# %% [markdown]
# <a href="https://colab.research.google.com/github/choeunseo0719/assignment-6/blob/main/20251254.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 01
#
# 리프 노드: (1개)
#
# 높이 4 최대 리프: 8
#
# 리프 - 내부 노드 차이: 1
#
# 항상 성립 여부: 성립함

# %% [markdown]
# ## 02
#
# 리프 개수: ⌈n/2⌉
#
# 리프와 내부 노드 관계: 리프 ≥ 내부 (최대 1개 차이)

# %% [markdown]
# ## 03
#
# 전위 순회: 5, 3, 3, 8, 7, 6, 9
#
# 중위 순회: 3, 3, 5, 6, 7, 8, 9
#
# 후위 순회: 3, 3, 6, 7, 9, 8, 5
#
# 중위 순회:
# BST는 왼쪽 < 루트 < 오른쪽 구조이므로
# 중위 순회 시 오름차순이 된다.

# %% [markdown]
# ## 04
#
# 검색 경로:
# 55 → 15 → 28 → 30

# %% [markdown]
# ## *05*![IMG_3760.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ## 06![IMG_3756.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ## 07
# ![IMG_3757.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ## 08
# ![IMG_3758.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ## 09
#
# max height: n - 1
# min height: log₂(n)
